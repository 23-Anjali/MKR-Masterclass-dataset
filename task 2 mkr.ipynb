# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Anjali\\notebooks\\Untitled Folder'

# %% [markdown]
# #  First dataset

# %%
df1 = pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\_Masterclass on - Whatsapp Marketing (Responses).xlsx')
df1
# Out:
#                   Timestamp    First Name Last Name          City Unnamed: 4  \
# 0   2020-08-29 11:31:02.261           Raj      Maru        Mumbai   whatsapp
# 1   2020-08-29 16:33:59.010       Prachi   Agarwal     Moradabad    whatsapp
# 2   2020-08-29 18:08:10.918  Paramananda       Deka      Guwahati   whatsapp
# 3   2020-08-29 19:36:26.061        Rajesh     Kumar     Raebareli   whatsapp
# 4   2020-08-29 19:40:57.353     Akanksha     Kunwar      Dehradun   whatsapp
# ..                      ...           ...       ...           ...        ...
# 384 2020-09-13 13:58:24.409        Nimesh     Desai          Pune   whatsapp
# 385 2020-09-13 13:58:54.267        Vedant    Musale          Pune   whatsapp
# 386 2020-09-13 14:10:46.382       Pushkar      Shah          Pune   whatsapp
# 387 2020-09-13 14:30:02.398      Satyajit     Kadam          Pune   whatsapp
# 388 2020-09-13 15:04:32.596         Sneha     Bugad  Ichalkaranji   whatsapp
#
#                    Unnamed: 5
# ...

# %%
df1.columns
# Out:
# Index(['Timestamp', 'First Name', 'Last Name', 'City', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %%
df1=df1.rename(columns = {'Unnamed: 4'  : 'x'  ,'Unnamed: 5' : 'y' , 'Timestamp' : 'Date'})

# %%
df1.dropna()
# Out:
#                        Date    First Name Last Name          City         x  \
# 0   2020-08-29 11:31:02.261           Raj      Maru        Mumbai  whatsapp
# 1   2020-08-29 16:33:59.010       Prachi   Agarwal     Moradabad   whatsapp
# 2   2020-08-29 18:08:10.918  Paramananda       Deka      Guwahati  whatsapp
# 3   2020-08-29 19:36:26.061        Rajesh     Kumar     Raebareli  whatsapp
# 4   2020-08-29 19:40:57.353     Akanksha     Kunwar      Dehradun  whatsapp
# ..                      ...           ...       ...           ...       ...
# 384 2020-09-13 13:58:24.409        Nimesh     Desai          Pune  whatsapp
# 385 2020-09-13 13:58:54.267        Vedant    Musale          Pune  whatsapp
# 386 2020-09-13 14:10:46.382       Pushkar      Shah          Pune  whatsapp
# 387 2020-09-13 14:30:02.398      Satyajit     Kadam          Pune  whatsapp
# 388 2020-09-13 15:04:32.596         Sneha     Bugad  Ichalkaranji  whatsapp
#
#                             y
# ...

# %%
df1=df1.drop(['x','y'] , axis =1)

# %%
df1['Date'] = pd.to_datetime(df1['Date']).dt.date

# %%
df1
# Out:
#            Date    First Name Last Name          City
# 0    2020-08-29           Raj      Maru        Mumbai
# 1    2020-08-29       Prachi   Agarwal     Moradabad
# 2    2020-08-29  Paramananda       Deka      Guwahati
# 3    2020-08-29        Rajesh     Kumar     Raebareli
# 4    2020-08-29     Akanksha     Kunwar      Dehradun
# ..          ...           ...       ...           ...
# 384  2020-09-13        Nimesh     Desai          Pune
# 385  2020-09-13        Vedant    Musale          Pune
# 386  2020-09-13       Pushkar      Shah          Pune
# 387  2020-09-13      Satyajit     Kadam          Pune
# 388  2020-09-13         Sneha     Bugad  Ichalkaranji
#
# [389 rows x 4 columns]

# %%
df1.insert(4,"NameofMasterclass",'Whatsapp Marketing', True)
df1
# Out:
#            Date    First Name Last Name          City   NameofMasterclass
# 0    2020-08-29           Raj      Maru        Mumbai  Whatsapp Marketing
# 1    2020-08-29       Prachi   Agarwal     Moradabad   Whatsapp Marketing
# 2    2020-08-29  Paramananda       Deka      Guwahati  Whatsapp Marketing
# 3    2020-08-29        Rajesh     Kumar     Raebareli  Whatsapp Marketing
# 4    2020-08-29     Akanksha     Kunwar      Dehradun  Whatsapp Marketing
# ..          ...           ...       ...           ...                 ...
# 384  2020-09-13        Nimesh     Desai          Pune  Whatsapp Marketing
# 385  2020-09-13        Vedant    Musale          Pune  Whatsapp Marketing
# 386  2020-09-13       Pushkar      Shah          Pune  Whatsapp Marketing
# 387  2020-09-13      Satyajit     Kadam          Pune  Whatsapp Marketing
# 388  2020-09-13         Sneha     Bugad  Ichalkaranji  Whatsapp Marketing
#
# [389 rows x 5 columns]

# %%
df1 = df1.replace(['New Delhi'],'Delhi')
df1 = df1.replace(['new delhi'],'Delhi')
df1 = df1.replace(['PUNE'],'Pune')
df1 = df1.replace(['pune'],'Pune')
df1 = df1.replace(['V.P.O - Mohanpur, DISTT. - Rewari (Haryana)'], 'Haryana')

# %%
df1= df1.sort_index(axis=1)
df1
# Out:
#              City        Date    First Name Last Name   NameofMasterclass
# 0          Mumbai  2020-08-29           Raj      Maru  Whatsapp Marketing
# 1      Moradabad   2020-08-29       Prachi   Agarwal   Whatsapp Marketing
# 2        Guwahati  2020-08-29  Paramananda       Deka  Whatsapp Marketing
# 3       Raebareli  2020-08-29        Rajesh     Kumar  Whatsapp Marketing
# 4        Dehradun  2020-08-29     Akanksha     Kunwar  Whatsapp Marketing
# ..            ...         ...           ...       ...                 ...
# 384          Pune  2020-09-13        Nimesh     Desai  Whatsapp Marketing
# 385          Pune  2020-09-13        Vedant    Musale  Whatsapp Marketing
# 386          Pune  2020-09-13       Pushkar      Shah  Whatsapp Marketing
# 387          Pune  2020-09-13      Satyajit     Kadam  Whatsapp Marketing
# 388  Ichalkaranji  2020-09-13         Sneha     Bugad  Whatsapp Marketing
#
# [389 rows x 5 columns]

# %%
df1.shape
# Out:
# (389, 5)

# %% [markdown]
# # Second dataset

# %%
df2 = pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\Basic Video Editing - Masterclass (Responses).xlsx')
df2
# Out:
#                   Timestamp         First Name        City     Last Name  \
# 0   2020-07-28 16:46:31.177            Samrita      Raipur           NaN
# 1   2020-07-28 16:46:43.534     Khushi Tiwari     Gurgaon            NaN
# 2   2020-07-28 16:48:02.362      Shreya Biswas      Bhilai           NaN
# 3   2020-07-28 16:49:58.147       Hardik Patni        Pune           NaN
# 4   2020-07-28 16:50:17.182  Anhad Preet Singh     Chennai           NaN
# ..                      ...                ...         ...           ...
# 581 2020-08-02 14:05:45.856            Kalyani        Pune           Jha
# 582 2020-08-02 20:13:55.905        Prathyusha   Kondapalli   Vangaveeti
# 583 2020-08-04 01:22:17.969          Munnawar         Pune  Nagarbawadi
# 584 2020-08-04 08:51:10.272             Souvik    Guwahati           das
# 585 2020-09-11 19:01:30.905              Manan        Pune      Sanghnai
#
#     Unnamed: 4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# ...

# %%
df2['Timestamp'] = pd.to_datetime(df2['Timestamp']).dt.date
df2
# Out:
#       Timestamp         First Name        City     Last Name Unnamed: 4
# 0    2020-07-28            Samrita      Raipur           NaN        NaN
# 1    2020-07-28     Khushi Tiwari     Gurgaon            NaN        NaN
# 2    2020-07-28      Shreya Biswas      Bhilai           NaN        NaN
# 3    2020-07-28       Hardik Patni        Pune           NaN        NaN
# 4    2020-07-28  Anhad Preet Singh     Chennai           NaN        NaN
# ..          ...                ...         ...           ...        ...
# 581  2020-08-02            Kalyani        Pune           Jha        NaN
# 582  2020-08-02        Prathyusha   Kondapalli   Vangaveeti         NaN
# 583  2020-08-04          Munnawar         Pune  Nagarbawadi         NaN
# 584  2020-08-04             Souvik    Guwahati           das        NaN
# 585  2020-09-11              Manan        Pune      Sanghnai        NaN
#
# [586 rows x 5 columns]

# %%
df2=df2.rename(columns = {'Unnamed: 4'  : 'x'   , 'Timestamp' : 'Date'})

# %%
df2=df2.drop(['x'] , axis =1)

# %%
df2.size
# Out:
# 2344

# %%
df2 = df2.dropna()

# %%
df2.tail(10)
# Out:
#            Date   First Name          City     Last Name
# 576  2020-08-02       Vinit   Patna(Bihar)         Kumar
# 577  2020-08-02      Shivtej          Pune        Jadhav
# 578  2020-08-02      PREETAM        Jaipur       CHAUHAN
# 579  2020-08-02      Ullas n        Mysuru       Bhargav
# 580  2020-08-02      Sheetal          Pune         Pitla
# 581  2020-08-02      Kalyani          Pune           Jha
# 582  2020-08-02  Prathyusha     Kondapalli   Vangaveeti
# 583  2020-08-04    Munnawar           Pune  Nagarbawadi
# 584  2020-08-04       Souvik      Guwahati           das
# 585  2020-09-11        Manan          Pune      Sanghnai

# %%
df2.insert(4,"NameofMasterclass",'Basic Video Editing', True)
df2
# Out:
#            Date   First Name        City     Last Name    NameofMasterclass
# 381  2020-07-30        saket        Pune      deshmukh  Basic Video Editing
# 382  2020-07-30    Abhiyansh  Gandhidham      Valechha  Basic Video Editing
# 383  2020-07-30        Ralph     Kolkata      Drozario  Basic Video Editing
# 384  2020-07-30     abhiraj       mumbai         pande  Basic Video Editing
# 385  2020-07-30        Sweta        Pune        Kumari  Basic Video Editing
# ..          ...          ...         ...           ...                  ...
# 581  2020-08-02      Kalyani        Pune           Jha  Basic Video Editing
# 582  2020-08-02  Prathyusha   Kondapalli   Vangaveeti   Basic Video Editing
# 583  2020-08-04    Munnawar         Pune  Nagarbawadi   Basic Video Editing
# 584  2020-08-04       Souvik    Guwahati           das  Basic Video Editing
# 585  2020-09-11        Manan        Pune      Sanghnai  Basic Video Editing
#
# [205 rows x 5 columns]

# %%
df2 = df2.replace(['Bareli , Distt- Raisen'],'Barielly')
df2= df2.replace(['Navi Mumbai'],'Mumbai')
df2 = df2.replace(['Bongaigaon, Assam'],'Assam')
df2 = df2.replace(['New Delhi'],'Delhi')

# %%
df2 = df2.sort_index(axis=1)
df2
# Out:
#            City        Date   First Name     Last Name    NameofMasterclass
# 381        Pune  2020-07-30        saket      deshmukh  Basic Video Editing
# 382  Gandhidham  2020-07-30    Abhiyansh      Valechha  Basic Video Editing
# 383     Kolkata  2020-07-30        Ralph      Drozario  Basic Video Editing
# 384      mumbai  2020-07-30     abhiraj          pande  Basic Video Editing
# 385        Pune  2020-07-30        Sweta        Kumari  Basic Video Editing
# ..          ...         ...          ...           ...                  ...
# 581        Pune  2020-08-02      Kalyani           Jha  Basic Video Editing
# 582  Kondapalli  2020-08-02  Prathyusha    Vangaveeti   Basic Video Editing
# 583        Pune  2020-08-04    Munnawar   Nagarbawadi   Basic Video Editing
# 584    Guwahati  2020-08-04       Souvik           das  Basic Video Editing
# 585        Pune  2020-09-11        Manan      Sanghnai  Basic Video Editing
#
# [205 rows x 5 columns]

# %%
df2.shape
# Out:
# (205, 5)

# %% [markdown]
# # Third dataset

# %%
df3 = pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\Masterclass - The Basics Of Digital Marketing (Responses).xlsx')
df3
# Out:
#                   Timestamp      First Name Last Name            City  \
# 0   2020-09-19 16:30:06.460         Deepali   Vandana          Mumbai
# 1   2020-09-19 17:18:17.638        Supriya     Glory       Bangalore
# 2   2020-09-19 19:29:09.356        Samiksha   Todaria        Dehradun
# 3   2020-09-20 03:33:16.894            Ajay  Kushwaha          Maihar
# 4   2020-09-20 16:50:17.189  Divya Sai Teja   Sindiri  Visakhapatnam
# ..                      ...             ...       ...             ...
# 239 2020-09-27 10:38:39.089           Vinay     Kumar   Visakhapatnam
# 240 2020-09-27 11:26:29.185          Sanjay     Kumar       Bangalore
# 241 2020-09-27 11:51:51.055          Shriya   Agarwal       Ghaziabad
# 242 2020-09-27 12:21:01.515           Diana      Dias          Mumbai
# 243 2020-09-27 13:21:24.403       Sangeeta     Mohta          Kolkata
#
#     Unnamed: 4                Unnamed: 5
# 0          DMC         DMCDeepaliVandana
# 1          DMC         DMCSupriya Glory
# ...

# %%
df3.insert(4,"NameofMasterclass",'The Basics Of Digital Marketing', True)
df3
# Out:
#                   Timestamp      First Name Last Name            City  \
# 0   2020-09-19 16:30:06.460         Deepali   Vandana          Mumbai
# 1   2020-09-19 17:18:17.638        Supriya     Glory       Bangalore
# 2   2020-09-19 19:29:09.356        Samiksha   Todaria        Dehradun
# 3   2020-09-20 03:33:16.894            Ajay  Kushwaha          Maihar
# 4   2020-09-20 16:50:17.189  Divya Sai Teja   Sindiri  Visakhapatnam
# ..                      ...             ...       ...             ...
# 239 2020-09-27 10:38:39.089           Vinay     Kumar   Visakhapatnam
# 240 2020-09-27 11:26:29.185          Sanjay     Kumar       Bangalore
# 241 2020-09-27 11:51:51.055          Shriya   Agarwal       Ghaziabad
# 242 2020-09-27 12:21:01.515           Diana      Dias          Mumbai
# 243 2020-09-27 13:21:24.403       Sangeeta     Mohta          Kolkata
#
#                    NameofMasterclass Unnamed: 4                Unnamed: 5
# ...

# %%
df3['Timestamp'] = pd.to_datetime(df3['Timestamp']).dt.date
df3
# Out:
#       Timestamp      First Name Last Name            City  \
# 0    2020-09-19         Deepali   Vandana          Mumbai
# 1    2020-09-19        Supriya     Glory       Bangalore
# 2    2020-09-19        Samiksha   Todaria        Dehradun
# 3    2020-09-20            Ajay  Kushwaha          Maihar
# 4    2020-09-20  Divya Sai Teja   Sindiri  Visakhapatnam
# ..          ...             ...       ...             ...
# 239  2020-09-27           Vinay     Kumar   Visakhapatnam
# 240  2020-09-27          Sanjay     Kumar       Bangalore
# 241  2020-09-27          Shriya   Agarwal       Ghaziabad
# 242  2020-09-27           Diana      Dias          Mumbai
# 243  2020-09-27       Sangeeta     Mohta          Kolkata
#
#                    NameofMasterclass Unnamed: 4                Unnamed: 5
# 0    The Basics Of Digital Marketing        DMC         DMCDeepaliVandana
# 1    The Basics Of Digital Marketing        DMC         DMCSupriya Glory
# ...

# %%
df3=df3.rename(columns = {'Unnamed: 4'  : 'x'  ,'Unnamed: 5' : 'y' , 'Timestamp' : 'Date'})

# %%
df3=df3.drop(['x','y'] , axis =1)

# %%
df3 =df3.dropna()
df3
# Out:
#            Date      First Name Last Name            City  \
# 0    2020-09-19         Deepali   Vandana          Mumbai
# 1    2020-09-19        Supriya     Glory       Bangalore
# 2    2020-09-19        Samiksha   Todaria        Dehradun
# 3    2020-09-20            Ajay  Kushwaha          Maihar
# 4    2020-09-20  Divya Sai Teja   Sindiri  Visakhapatnam
# ..          ...             ...       ...             ...
# 239  2020-09-27           Vinay     Kumar   Visakhapatnam
# 240  2020-09-27          Sanjay     Kumar       Bangalore
# 241  2020-09-27          Shriya   Agarwal       Ghaziabad
# 242  2020-09-27           Diana      Dias          Mumbai
# 243  2020-09-27       Sangeeta     Mohta          Kolkata
#
#                    NameofMasterclass
# 0    The Basics Of Digital Marketing
# 1    The Basics Of Digital Marketing
# 2    The Basics Of Digital Marketing
# 3    The Basics Of Digital Marketing
# 4    The Basics Of Digital Marketing
# ..                               ...
# ...

# %%
df3 = df3.replace(['Karnal, Haryana'],'Haryana')
df3= df3.replace(['Navi Mumbai-401201'],'Mumbai')
df3 = df3.replace(['South West Delhi'],'Delhi')
df3 = df3.replace(['New Delhi'],'Delhi')
df3 = df3.replace(['WEST DELHI'],'Delhi')
df3 = df3.replace(['bangalore'],'Bengaluru')

# %%
df3 = df3.sort_index(axis=1)
df3
# Out:
#                City        Date      First Name Last Name  \
# 0            Mumbai  2020-09-19         Deepali   Vandana
# 1        Bangalore   2020-09-19        Supriya     Glory
# 2          Dehradun  2020-09-19        Samiksha   Todaria
# 3            Maihar  2020-09-20            Ajay  Kushwaha
# 4    Visakhapatnam   2020-09-20  Divya Sai Teja   Sindiri
# ..              ...         ...             ...       ...
# 239   Visakhapatnam  2020-09-27           Vinay     Kumar
# 240       Bangalore  2020-09-27          Sanjay     Kumar
# 241       Ghaziabad  2020-09-27          Shriya   Agarwal
# 242          Mumbai  2020-09-27           Diana      Dias
# 243         Kolkata  2020-09-27       Sangeeta     Mohta
#
#                    NameofMasterclass
# 0    The Basics Of Digital Marketing
# 1    The Basics Of Digital Marketing
# 2    The Basics Of Digital Marketing
# 3    The Basics Of Digital Marketing
# 4    The Basics Of Digital Marketing
# ..                               ...
# ...

# %%
df3.shape
# Out:
# (244, 5)

# %% [markdown]
# # Fourth dataset

# %%
df4 = pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\Masterclass - The Basics Of Excel (Responses) (1).xlsx')
df4
# Out:
#                   Timestamp    First Name  Last Name                 City  \
# 0   2020-09-28 00:10:58.066      Pranshu   Bhatnagar            Moradabad
# 1   2020-09-28 07:17:13.080        Kumari     Garima                Delhi
# 2   2020-09-28 09:12:18.512  Damarakeswar   Guddanti                ELURU
# 3   2020-09-28 09:41:07.900        Manish     Bharti            Bangalore
# 4   2020-09-28 10:59:00.443        Rakesh   Tripathi                 Pune
# ..                      ...           ...        ...                  ...
# 652 2020-10-18 14:21:12.718         Jisna       Jose  Sunset Ave, Windsor
# 653 2020-10-18 14:22:58.630      Amrutlal    Agarwal                 Pune
# 654 2020-10-18 14:39:38.173          Jeff      Daisy             Malaysia
# 655 2020-10-18 17:06:09.080      Sulekha          .              Lucknow
# 656 2020-10-03 17:27:48.144          pune       pune                 pune
#
#      Unnamed: 4
# 0           1.0
# 1          35.0
# 2           1.0
# ...

# %%
df4.insert(4,"NameofMasterclass",'The Basics Of Excel', True)
df4
# Out:
#                   Timestamp    First Name  Last Name                 City  \
# 0   2020-09-28 00:10:58.066      Pranshu   Bhatnagar            Moradabad
# 1   2020-09-28 07:17:13.080        Kumari     Garima                Delhi
# 2   2020-09-28 09:12:18.512  Damarakeswar   Guddanti                ELURU
# 3   2020-09-28 09:41:07.900        Manish     Bharti            Bangalore
# 4   2020-09-28 10:59:00.443        Rakesh   Tripathi                 Pune
# ..                      ...           ...        ...                  ...
# 652 2020-10-18 14:21:12.718         Jisna       Jose  Sunset Ave, Windsor
# 653 2020-10-18 14:22:58.630      Amrutlal    Agarwal                 Pune
# 654 2020-10-18 14:39:38.173          Jeff      Daisy             Malaysia
# 655 2020-10-18 17:06:09.080      Sulekha          .              Lucknow
# 656 2020-10-03 17:27:48.144          pune       pune                 pune
#
#        NameofMasterclass  Unnamed: 4
# 0    The Basics Of Excel         1.0
# ...

# %%
df4['Timestamp'] = pd.to_datetime(df4['Timestamp']).dt.date
df4
# Out:
#       Timestamp    First Name  Last Name                 City  \
# 0    2020-09-28      Pranshu   Bhatnagar            Moradabad
# 1    2020-09-28        Kumari     Garima                Delhi
# 2    2020-09-28  Damarakeswar   Guddanti                ELURU
# 3    2020-09-28        Manish     Bharti            Bangalore
# 4    2020-09-28        Rakesh   Tripathi                 Pune
# ..          ...           ...        ...                  ...
# 652  2020-10-18         Jisna       Jose  Sunset Ave, Windsor
# 653  2020-10-18      Amrutlal    Agarwal                 Pune
# 654  2020-10-18          Jeff      Daisy             Malaysia
# 655  2020-10-18      Sulekha          .              Lucknow
# 656  2020-10-03          pune       pune                 pune
#
#        NameofMasterclass  Unnamed: 4
# 0    The Basics Of Excel         1.0
# 1    The Basics Of Excel        35.0
# 2    The Basics Of Excel         1.0
# 3    The Basics Of Excel        17.0
# ...

# %%
df4=df4.rename(columns = {'Unnamed: 4'  : 'x' , 'Timestamp' : 'Date'})

# %%
df4=df4.drop(['x'] , axis =1)

# %%
df4 = df4.dropna()
df4
# Out:
#            Date    First Name  Last Name                 City  \
# 0    2020-09-28      Pranshu   Bhatnagar            Moradabad
# 1    2020-09-28        Kumari     Garima                Delhi
# 2    2020-09-28  Damarakeswar   Guddanti                ELURU
# 3    2020-09-28        Manish     Bharti            Bangalore
# 4    2020-09-28        Rakesh   Tripathi                 Pune
# ..          ...           ...        ...                  ...
# 652  2020-10-18         Jisna       Jose  Sunset Ave, Windsor
# 653  2020-10-18      Amrutlal    Agarwal                 Pune
# 654  2020-10-18          Jeff      Daisy             Malaysia
# 655  2020-10-18      Sulekha          .              Lucknow
# 656  2020-10-03          pune       pune                 pune
#
#        NameofMasterclass
# 0    The Basics Of Excel
# 1    The Basics Of Excel
# 2    The Basics Of Excel
# 3    The Basics Of Excel
# 4    The Basics Of Excel
# ..                   ...
# 652  The Basics Of Excel
# ...

# %%
df4 = df4.replace(['Goregaon w, Mumbai'],'Mumbai')
df4= df4.replace(['Near Dikshant international school'],'not defined')
df4 = df4.replace(['Navi Mumbai - 410210'],'Mumbai')
df4 = df4.replace(['New Delhi'],'Delhi')
df4 = df4.replace(['NORTH WEST DELHI'],'Delhi')
df4 = df4.replace(['North West Delhi'], 'Delhi')
df4 = df4.replace(['San jose del monte'],'not defined')
df4 = df4.replace(['Las Piñas City, Metro Manila'] , 'not defined')
df4 = df4.replace(['AHMEDABAD '], 'Ahmedabad')
df4 = df4.replace(['Navi Mumbai, New Panvel'], 'Mumbai')
df4 = df4.replace(['Visakhapatnam, Andhra Pradesh, India'] , ' Andhra Pradesh')

# %%
df4=df4.sort_index(axis=1)
df4
# Out:
#                     City        Date    First Name  Last Name  \
# 0              Moradabad  2020-09-28      Pranshu   Bhatnagar
# 1                  Delhi  2020-09-28        Kumari     Garima
# 2                  ELURU  2020-09-28  Damarakeswar   Guddanti
# 3              Bangalore  2020-09-28        Manish     Bharti
# 4                   Pune  2020-09-28        Rakesh   Tripathi
# ..                   ...         ...           ...        ...
# 652  Sunset Ave, Windsor  2020-10-18         Jisna       Jose
# 653                 Pune  2020-10-18      Amrutlal    Agarwal
# 654             Malaysia  2020-10-18          Jeff      Daisy
# 655             Lucknow   2020-10-18      Sulekha          .
# 656                 pune  2020-10-03          pune       pune
#
#        NameofMasterclass
# 0    The Basics Of Excel
# 1    The Basics Of Excel
# 2    The Basics Of Excel
# 3    The Basics Of Excel
# 4    The Basics Of Excel
# ..                   ...
# 652  The Basics Of Excel
# ...

# %%
df4.shape
# Out:
# (657, 5)

# %% [markdown]
# # Fifth dataset

# %%
df5 = pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\Masterclass on Basics of Canva - a Graphic Design Platform (Responses).xlsx')
df5
# Out:
#                   Timestamp First Name  Last Name        City Unnamed: 4  \
# 0   2020-08-09 21:10:59.330      Anuja    Kharkar      Bhopal      canva
# 1   2020-08-09 21:27:42.550  Abhishek   Bhardwaj    New delhi      canva
# 2   2020-08-09 21:29:55.608    Manjiri     Sonone        Pune      canva
# 3   2020-08-09 21:30:34.752    Anthima      Singh  Hyderabad       canva
# 4   2020-08-09 21:36:48.633    Dharini       Shah      Mumbai      canva
# ..                      ...        ...        ...         ...        ...
# 661 2020-08-23 11:11:02.135       Neha          H        Pune      canva
# 662 2020-08-23 12:14:59.449     Radha      Ranade        Pune      canva
# 663 2020-08-23 14:05:04.953     Namita       Soni       Korba      canva
# 664 2020-08-23 14:05:46.067    Swapnil      Nikam  Aurangabad      canva
# 665 2020-08-23 14:12:46.954    Darshan          M      mysore      canva
#
#                   Unnamed: 5
# 0          canvaAnujaKharkar
# 1    canvaAbhishek Bhardwaj
# ...

# %%
df5.insert(4,"NameofMasterclass",'Masterclass on Basics of Canva - a Graphic Design Platform', True)
df5
# Out:
#                   Timestamp First Name  Last Name        City  \
# 0   2020-08-09 21:10:59.330      Anuja    Kharkar      Bhopal
# 1   2020-08-09 21:27:42.550  Abhishek   Bhardwaj    New delhi
# 2   2020-08-09 21:29:55.608    Manjiri     Sonone        Pune
# 3   2020-08-09 21:30:34.752    Anthima      Singh  Hyderabad
# 4   2020-08-09 21:36:48.633    Dharini       Shah      Mumbai
# ..                      ...        ...        ...         ...
# 661 2020-08-23 11:11:02.135       Neha          H        Pune
# 662 2020-08-23 12:14:59.449     Radha      Ranade        Pune
# 663 2020-08-23 14:05:04.953     Namita       Soni       Korba
# 664 2020-08-23 14:05:46.067    Swapnil      Nikam  Aurangabad
# 665 2020-08-23 14:12:46.954    Darshan          M      mysore
#
#                                      NameofMasterclass Unnamed: 4  \
# 0    Masterclass on Basics of Canva - a Graphic Des...      canva
# 1    Masterclass on Basics of Canva - a Graphic Des...      canva
# ...

# %%
df5=df5.rename(columns = {'Unnamed: 4'  : 'x' , 'Unnamed: 5' : 'y' ,'Timestamp': 'Date' })

# %%
df5 = df5.drop(['x' , 'y'] , axis =1)

# %%
df5 = df5.dropna()
df5
# Out:
#                        Date First Name  Last Name        City  \
# 0   2020-08-09 21:10:59.330      Anuja    Kharkar      Bhopal
# 1   2020-08-09 21:27:42.550  Abhishek   Bhardwaj    New delhi
# 2   2020-08-09 21:29:55.608    Manjiri     Sonone        Pune
# 3   2020-08-09 21:30:34.752    Anthima      Singh  Hyderabad
# 4   2020-08-09 21:36:48.633    Dharini       Shah      Mumbai
# ..                      ...        ...        ...         ...
# 661 2020-08-23 11:11:02.135       Neha          H        Pune
# 662 2020-08-23 12:14:59.449     Radha      Ranade        Pune
# 663 2020-08-23 14:05:04.953     Namita       Soni       Korba
# 664 2020-08-23 14:05:46.067    Swapnil      Nikam  Aurangabad
# 665 2020-08-23 14:12:46.954    Darshan          M      mysore
#
#                                      NameofMasterclass
# 0    Masterclass on Basics of Canva - a Graphic Des...
# 1    Masterclass on Basics of Canva - a Graphic Des...
# 2    Masterclass on Basics of Canva - a Graphic Des...
# ...

# %%
df5['Date'] = pd.to_datetime(df5['Date']).dt.date
df5
# Out:
#            Date First Name  Last Name        City  \
# 0    2020-08-09      Anuja    Kharkar      Bhopal
# 1    2020-08-09  Abhishek   Bhardwaj    New delhi
# 2    2020-08-09    Manjiri     Sonone        Pune
# 3    2020-08-09    Anthima      Singh  Hyderabad
# 4    2020-08-09    Dharini       Shah      Mumbai
# ..          ...        ...        ...         ...
# 661  2020-08-23       Neha          H        Pune
# 662  2020-08-23     Radha      Ranade        Pune
# 663  2020-08-23     Namita       Soni       Korba
# 664  2020-08-23    Swapnil      Nikam  Aurangabad
# 665  2020-08-23    Darshan          M      mysore
#
#                                      NameofMasterclass
# 0    Masterclass on Basics of Canva - a Graphic Des...
# 1    Masterclass on Basics of Canva - a Graphic Des...
# 2    Masterclass on Basics of Canva - a Graphic Des...
# 3    Masterclass on Basics of Canva - a Graphic Des...
# 4    Masterclass on Basics of Canva - a Graphic Des...
# ...

# %%
df5 = df5.replace(['mumbai'],'Mumbai')
df5=  df5.replace(['NEW DELHI'],'Delhi')
df5 = df5.replace(['Navi Mumbai - 410210'],'Mumbai')
df5 = df5.replace(['New Delhi'],'Delhi')
df5 = df5.replace(['delhi'],'Delhi')
df5 = df5.replace(['Haryana ,Delhi'], 'Delhi')
df5 = df5.replace(['North West Delhi'],'Delhi')

# %%
df5= df5.sort_index(axis=1)
df5
# Out:
#            City        Date First Name  Last Name  \
# 0        Bhopal  2020-08-09      Anuja    Kharkar
# 1     New delhi  2020-08-09  Abhishek   Bhardwaj
# 2          Pune  2020-08-09    Manjiri     Sonone
# 3    Hyderabad   2020-08-09    Anthima      Singh
# 4        Mumbai  2020-08-09    Dharini       Shah
# ..          ...         ...        ...        ...
# 661        Pune  2020-08-23       Neha          H
# 662        Pune  2020-08-23     Radha      Ranade
# 663       Korba  2020-08-23     Namita       Soni
# 664  Aurangabad  2020-08-23    Swapnil      Nikam
# 665      mysore  2020-08-23    Darshan          M
#
#                                      NameofMasterclass
# 0    Masterclass on Basics of Canva - a Graphic Des...
# 1    Masterclass on Basics of Canva - a Graphic Des...
# 2    Masterclass on Basics of Canva - a Graphic Des...
# 3    Masterclass on Basics of Canva - a Graphic Des...
# 4    Masterclass on Basics of Canva - a Graphic Des...
# ...

# %%
df5.shape
# Out:
# (666, 5)

# %% [markdown]
# # Sixth dataset

# %%
df6 = pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\Public Speaking - Masterclass (Responses).xlsx')
df6
# Out:
#                   Timestamp  First Name    Last Name            City  \
# 0   2020-08-02 15:05:28.216       saket     deshmukh            Pune
# 1   2020-08-02 22:13:36.424     Mishika       Sharma         Gurgaon
# 2   2020-08-02 22:16:43.616      Diksha          Deb  Silchar, Assam
# 3   2020-08-02 22:17:19.184      Lohith    Bollineni         Chennai
# 4   2020-08-02 22:20:47.635      Rutuja     Ghorpade            Pune
# ..                      ...         ...          ...             ...
# 190 2020-08-09 12:43:14.707       Ronak         Shah          Mumbai
# 191 2020-08-09 12:53:47.614    Vaibhav         Daksh           Delhi
# 192 2020-08-09 13:03:52.081  Vaishnavi   Kshirsagar             Pune
# 193 2020-08-09 13:17:34.780     Vaibhav        Daksh       Delhi ncr
# 194 2020-08-09 14:03:36.349    Richelle       Aranjo            Pune
#
#     Unnamed: 4                   Unnamed: 5
# 0       Public          Publicsaketdeshmukh
# 1       Public          PublicMishikaSharma
# ...

# %%
df6.insert(4,"NameofMasterclass",'Public Speaking - Masterclass', True)
df6
# Out:
#                   Timestamp  First Name    Last Name            City  \
# 0   2020-08-02 15:05:28.216       saket     deshmukh            Pune
# 1   2020-08-02 22:13:36.424     Mishika       Sharma         Gurgaon
# 2   2020-08-02 22:16:43.616      Diksha          Deb  Silchar, Assam
# 3   2020-08-02 22:17:19.184      Lohith    Bollineni         Chennai
# 4   2020-08-02 22:20:47.635      Rutuja     Ghorpade            Pune
# ..                      ...         ...          ...             ...
# 190 2020-08-09 12:43:14.707       Ronak         Shah          Mumbai
# 191 2020-08-09 12:53:47.614    Vaibhav         Daksh           Delhi
# 192 2020-08-09 13:03:52.081  Vaishnavi   Kshirsagar             Pune
# 193 2020-08-09 13:17:34.780     Vaibhav        Daksh       Delhi ncr
# 194 2020-08-09 14:03:36.349    Richelle       Aranjo            Pune
#
#                  NameofMasterclass Unnamed: 4                   Unnamed: 5
# ...

# %%
df6['Timestamp'] = pd.to_datetime(df6['Timestamp']).dt.date
df6
# Out:
#       Timestamp  First Name    Last Name            City  \
# 0    2020-08-02       saket     deshmukh            Pune
# 1    2020-08-02     Mishika       Sharma         Gurgaon
# 2    2020-08-02      Diksha          Deb  Silchar, Assam
# 3    2020-08-02      Lohith    Bollineni         Chennai
# 4    2020-08-02      Rutuja     Ghorpade            Pune
# ..          ...         ...          ...             ...
# 190  2020-08-09       Ronak         Shah          Mumbai
# 191  2020-08-09    Vaibhav         Daksh           Delhi
# 192  2020-08-09  Vaishnavi   Kshirsagar             Pune
# 193  2020-08-09     Vaibhav        Daksh       Delhi ncr
# 194  2020-08-09    Richelle       Aranjo            Pune
#
#                  NameofMasterclass Unnamed: 4                   Unnamed: 5
# 0    Public Speaking - Masterclass     Public          Publicsaketdeshmukh
# 1    Public Speaking - Masterclass     Public          PublicMishikaSharma
# ...

# %%
df6=df6.rename(columns = {'Unnamed: 4'  : 'x' , 'Unnamed: 5' : 'y' ,'Timestamp': 'Date' })

# %%
df6 = df6.drop(['x', 'y'] , axis = 1)

# %%
df6 = df6.dropna()
df6
# Out:
#            Date  First Name    Last Name            City  \
# 0    2020-08-02       saket     deshmukh            Pune
# 1    2020-08-02     Mishika       Sharma         Gurgaon
# 2    2020-08-02      Diksha          Deb  Silchar, Assam
# 3    2020-08-02      Lohith    Bollineni         Chennai
# 4    2020-08-02      Rutuja     Ghorpade            Pune
# ..          ...         ...          ...             ...
# 190  2020-08-09       Ronak         Shah          Mumbai
# 191  2020-08-09    Vaibhav         Daksh           Delhi
# 192  2020-08-09  Vaishnavi   Kshirsagar             Pune
# 193  2020-08-09     Vaibhav        Daksh       Delhi ncr
# 194  2020-08-09    Richelle       Aranjo            Pune
#
#                  NameofMasterclass
# 0    Public Speaking - Masterclass
# 1    Public Speaking - Masterclass
# 2    Public Speaking - Masterclass
# 3    Public Speaking - Masterclass
# 4    Public Speaking - Masterclass
# ..                             ...
# ...

# %%
df6 =df6.replace(['gOA'], 'Goa')
df6 =df6.replace(['Navi Mumbai-410210'],'Mumbai')

# %%
df6 = df6.sort_index(axis=1)
df6
# Out:
#                City        Date  First Name    Last Name  \
# 0              Pune  2020-08-02       saket     deshmukh
# 1           Gurgaon  2020-08-02     Mishika       Sharma
# 2    Silchar, Assam  2020-08-02      Diksha          Deb
# 3           Chennai  2020-08-02      Lohith    Bollineni
# 4              Pune  2020-08-02      Rutuja     Ghorpade
# ..              ...         ...         ...          ...
# 190          Mumbai  2020-08-09       Ronak         Shah
# 191           Delhi  2020-08-09    Vaibhav         Daksh
# 192            Pune  2020-08-09  Vaishnavi   Kshirsagar
# 193       Delhi ncr  2020-08-09     Vaibhav        Daksh
# 194            Pune  2020-08-09    Richelle       Aranjo
#
#                  NameofMasterclass
# 0    Public Speaking - Masterclass
# 1    Public Speaking - Masterclass
# 2    Public Speaking - Masterclass
# 3    Public Speaking - Masterclass
# 4    Public Speaking - Masterclass
# ..                             ...
# ...

# %%
df6.shape
# Out:
# (195, 5)

# %% [markdown]
# # Seventh dataset

# %%
df7 = pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\The Podcast - Masterclass (Responses).xlsx')
df7
# Out:
#                   Timestamp First Name Last Name                City  \
# 0   2020-08-14 07:58:54.049      JYOTI   GOSWAMI          Bikramganj
# 1   2020-08-14 09:31:51.186       Anil     Kumar               Arwal
# 2   2020-08-14 12:59:11.465   Sandhya     Shakya            Banglore
# 3   2020-08-14 15:23:18.877    Rajnish     Tomar               Delhi
# 4   2020-08-14 16:21:04.926    Sheril   Gaikwad              Mumbai
# ..                      ...        ...       ...                 ...
# 218 2020-08-30 12:42:07.754   Samyamoy   Debnath              Bhopal
# 219 2020-08-30 12:46:35.856     Anshul       Jha  Bhubaneswar,Patna
# 220 2020-08-30 13:05:30.867     Prasad         B               Delhi
# 221 2020-08-30 13:26:48.941    Samarth      Jain            Guwahati
# 222 2020-08-30 14:05:12.357      Summy   Anthony           New Delhi
#
#     Unnamed: 4              Unnamed: 5
# 0      podcast     podcastJYOTIGOSWAMI
# 1      podcast        podcastAnilKumar
# ...

# %%
df7.insert(4,"NameofMasterclass",'The Podcast - Masterclass', True)
df7
# Out:
#                   Timestamp First Name Last Name                City  \
# 0   2020-08-14 07:58:54.049      JYOTI   GOSWAMI          Bikramganj
# 1   2020-08-14 09:31:51.186       Anil     Kumar               Arwal
# 2   2020-08-14 12:59:11.465   Sandhya     Shakya            Banglore
# 3   2020-08-14 15:23:18.877    Rajnish     Tomar               Delhi
# 4   2020-08-14 16:21:04.926    Sheril   Gaikwad              Mumbai
# ..                      ...        ...       ...                 ...
# 218 2020-08-30 12:42:07.754   Samyamoy   Debnath              Bhopal
# 219 2020-08-30 12:46:35.856     Anshul       Jha  Bhubaneswar,Patna
# 220 2020-08-30 13:05:30.867     Prasad         B               Delhi
# 221 2020-08-30 13:26:48.941    Samarth      Jain            Guwahati
# 222 2020-08-30 14:05:12.357      Summy   Anthony           New Delhi
#
#              NameofMasterclass Unnamed: 4              Unnamed: 5
# 0    The Podcast - Masterclass    podcast     podcastJYOTIGOSWAMI
# ...

# %%
df7['Timestamp'] = pd.to_datetime(df7['Timestamp']).dt.date
df7
# Out:
#       Timestamp First Name Last Name                City  \
# 0    2020-08-14      JYOTI   GOSWAMI          Bikramganj
# 1    2020-08-14       Anil     Kumar               Arwal
# 2    2020-08-14   Sandhya     Shakya            Banglore
# 3    2020-08-14    Rajnish     Tomar               Delhi
# 4    2020-08-14    Sheril   Gaikwad              Mumbai
# ..          ...        ...       ...                 ...
# 218  2020-08-30   Samyamoy   Debnath              Bhopal
# 219  2020-08-30     Anshul       Jha  Bhubaneswar,Patna
# 220  2020-08-30     Prasad         B               Delhi
# 221  2020-08-30    Samarth      Jain            Guwahati
# 222  2020-08-30      Summy   Anthony           New Delhi
#
#              NameofMasterclass Unnamed: 4              Unnamed: 5
# 0    The Podcast - Masterclass    podcast     podcastJYOTIGOSWAMI
# 1    The Podcast - Masterclass    podcast        podcastAnilKumar
# 2    The Podcast - Masterclass    podcast   podcastSandhya Shakya
# ...

# %%
df7=df7.rename(columns = {'Unnamed: 4'  : 'x' , 'Unnamed: 5' : 'y' ,'Timestamp': 'Date' })

# %%
df7 = df7.drop(['x','y'] , axis = 1)

# %%
df7 =  df7.dropna()
df7
# Out:
#            Date First Name Last Name                City  \
# 0    2020-08-14      JYOTI   GOSWAMI          Bikramganj
# 1    2020-08-14       Anil     Kumar               Arwal
# 2    2020-08-14   Sandhya     Shakya            Banglore
# 3    2020-08-14    Rajnish     Tomar               Delhi
# 4    2020-08-14    Sheril   Gaikwad              Mumbai
# ..          ...        ...       ...                 ...
# 218  2020-08-30   Samyamoy   Debnath              Bhopal
# 219  2020-08-30     Anshul       Jha  Bhubaneswar,Patna
# 220  2020-08-30     Prasad         B               Delhi
# 221  2020-08-30    Samarth      Jain            Guwahati
# 222  2020-08-30      Summy   Anthony           New Delhi
#
#              NameofMasterclass
# 0    The Podcast - Masterclass
# 1    The Podcast - Masterclass
# 2    The Podcast - Masterclass
# 3    The Podcast - Masterclass
# 4    The Podcast - Masterclass
# ..                         ...
# 218  The Podcast - Masterclass
# ...

# %%
df7 = df7.sort_index(axis=1)
df7
# Out:
#                    City        Date First Name Last Name  \
# 0            Bikramganj  2020-08-14      JYOTI   GOSWAMI
# 1                 Arwal  2020-08-14       Anil     Kumar
# 2              Banglore  2020-08-14   Sandhya     Shakya
# 3                 Delhi  2020-08-14    Rajnish     Tomar
# 4               Mumbai   2020-08-14    Sheril   Gaikwad
# ..                  ...         ...        ...       ...
# 218              Bhopal  2020-08-30   Samyamoy   Debnath
# 219  Bhubaneswar,Patna   2020-08-30     Anshul       Jha
# 220               Delhi  2020-08-30     Prasad         B
# 221            Guwahati  2020-08-30    Samarth      Jain
# 222           New Delhi  2020-08-30      Summy   Anthony
#
#              NameofMasterclass
# 0    The Podcast - Masterclass
# 1    The Podcast - Masterclass
# 2    The Podcast - Masterclass
# 3    The Podcast - Masterclass
# 4    The Podcast - Masterclass
# ..                         ...
# 218  The Podcast - Masterclass
# ...

# %%
df7 = df7.replace(['Vashi, Navi Mumbai'],'Mumbai')
df7 = df7.replace(['I want to attend '],'not defined')
df7 = df7.replace(['Faridabad, Haryana'], 'Haryana')

# %%
df7.shape
# Out:
# (223, 5)

# %%
dataset = pd.concat([df1, df2 , df3 , df4 , df5 , df6 , df7])

# %%
dataset
# Out:
#                    City        Date    First Name Last Name  \
# 0                Mumbai  2020-08-29           Raj      Maru
# 1            Moradabad   2020-08-29       Prachi   Agarwal
# 2              Guwahati  2020-08-29  Paramananda       Deka
# 3             Raebareli  2020-08-29        Rajesh     Kumar
# 4              Dehradun  2020-08-29     Akanksha     Kunwar
# ..                  ...         ...           ...       ...
# 218              Bhopal  2020-08-30      Samyamoy   Debnath
# 219  Bhubaneswar,Patna   2020-08-30        Anshul       Jha
# 220               Delhi  2020-08-30        Prasad         B
# 221            Guwahati  2020-08-30       Samarth      Jain
# 222           New Delhi  2020-08-30         Summy   Anthony
#
#              NameofMasterclass
# 0           Whatsapp Marketing
# 1           Whatsapp Marketing
# 2           Whatsapp Marketing
# 3           Whatsapp Marketing
# 4           Whatsapp Marketing
# ..                         ...
# ...

# %%
dataset.shape
# Out:
# (2579, 5)

# %%
dataset.City.unique()
# Out:
# array(['Mumbai', 'Moradabad ', 'Guwahati', 'Raebareli', 'Dehradun',
#        'Assam', 'Lucknow', 'Jabalpur', 'Jorhat', 'Vadodara', 'Bhilai',
#        'Kurukshetra', 'CHAMARAJNAGAR', 'Pune', 'Bangalore', 'Bhopal',
#        'Siliguri', 'Kharghar, Navi Mumbai - 410210', 'Rewari',
#        'Visakhapatnam ', 'Durg', 'Gwalior', 'Hyderabad', 'Gurugram',
#        'Delhi', 'Delhi ', 'Silchar', 'Ahmednagar', 'Rupnagar',
#        'Madhya Pradesh', 'Kalyan', 'LUCKNOW', 'Noida', 'Bengaluru',
#        'Sunyani', 'Bangalore ', 'Udaipur', 'Indore', 'Saharanpur',
#        'Madurai', 'Ujjain', 'Gurgaon', 'Jalandhar', 'Faridabad',
#        'gurgoan ', 'Tezpur', 'Jaipur', 'Chennai', 'Thane', 'Gurgaon ',
#        'noida', 'Kolhapur', 'jaipur', 'Kochi', 'Gandhinagar', 'Mumbai ',
#        'Patna', 'Lusaka', 'Auragabad', 'BENGALURU', 'Aurangabad', 'Jalna',
#        'Akola', 'Deulgaon Raja,Buldana', 'Jalna ', 'Buldhana', 'Calicut',
#        'MUMBAI', 'Shimla', 'LATUR', 'Ballabgarh', 'Bidar', 'Gurugram ',
# ...

# %%
dataset.columns
# Out:
# Index(['City', 'Date', 'First Name', 'Last Name', 'NameofMasterclass'], dtype='object')

# %%
dataset=dataset.rename(columns = {'First Name'  : 'FirstName' , 'Last Name' : 'LastName' })
dataset
# Out:
#                    City        Date     FirstName  LastName  \
# 0                Mumbai  2020-08-29           Raj      Maru
# 1            Moradabad   2020-08-29       Prachi   Agarwal
# 2              Guwahati  2020-08-29  Paramananda       Deka
# 3             Raebareli  2020-08-29        Rajesh     Kumar
# 4              Dehradun  2020-08-29     Akanksha     Kunwar
# ..                  ...         ...           ...       ...
# 218              Bhopal  2020-08-30      Samyamoy   Debnath
# 219  Bhubaneswar,Patna   2020-08-30        Anshul       Jha
# 220               Delhi  2020-08-30        Prasad         B
# 221            Guwahati  2020-08-30       Samarth      Jain
# 222           New Delhi  2020-08-30         Summy   Anthony
#
#              NameofMasterclass
# 0           Whatsapp Marketing
# 1           Whatsapp Marketing
# 2           Whatsapp Marketing
# 3           Whatsapp Marketing
# 4           Whatsapp Marketing
# ..                         ...
# ...

# %%
dataset.NameofMasterclass.unique()
# Out:
# array(['Whatsapp Marketing', 'Basic Video Editing',
#        'The Basics Of Digital Marketing', 'The Basics Of Excel',
#        'Masterclass on Basics of Canva - a Graphic Design Platform',
#        'Public Speaking - Masterclass', 'The Podcast - Masterclass'],
#       dtype=object)

# %%
dataset.NameofMasterclass[dataset.NameofMasterclass == 'Whatsapp Marketing']=0
dataset.NameofMasterclass[dataset.NameofMasterclass == 'The Basics Of Digital Marketing']=1
dataset.NameofMasterclass[dataset.NameofMasterclass == 'The Basics Of Excel']=2
dataset.NameofMasterclass[dataset.NameofMasterclass == 'Masterclass on Basics of Canva - a Graphic Design Platform']=3
dataset.NameofMasterclass[dataset.NameofMasterclass == 'Public Speaking - Masterclass']=4
dataset.NameofMasterclass[dataset.NameofMasterclass == 'Basic Video Editing']=5
dataset.NameofMasterclass[dataset.NameofMasterclass == 'The Podcast - Masterclass']=6

# %%
dataset.columns
# Out:
# Index(['City', 'Date', 'FirstName', 'LastName', 'NameofMasterclass'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2579 entries, 0 to 222
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               2579 non-null   object
#  1   Date               2579 non-null   object
#  2   FirstName          2579 non-null   object
#  3   LastName           2579 non-null   object
#  4   NameofMasterclass  2579 non-null   object
# dtypes: object(5)
# memory usage: 120.9+ KB

# %%
dataset['Date']= pd.to_datetime(dataset['Date'])
dataset['Date'].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 218    2020
# 219    2020
# 220    2020
# 221    2020
# 222    2020
# Name: Date, Length: 2579, dtype: int64

# %%
dataset['Date'].dt.day
# Out:
# 0      29
# 1      29
# 2      29
# 3      29
# 4      29
#        ..
# 218    30
# 219    30
# 220    30
# 221    30
# 222    30
# Name: Date, Length: 2579, dtype: int64

# %%
dataset['Date'].dt.month
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 218    8
# 219    8
# 220    8
# 221    8
# 222    8
# Name: Date, Length: 2579, dtype: int64

# %%
dataset['year']=dataset['Date'].dt.year
dataset['month']=dataset['Date'].dt.month
dataset['day']=dataset['Date'].dt.day
dataset
# Out:
#                    City       Date     FirstName  LastName NameofMasterclass  \
# 0                Mumbai 2020-08-29           Raj      Maru                 0
# 1            Moradabad  2020-08-29       Prachi   Agarwal                  0
# 2              Guwahati 2020-08-29  Paramananda       Deka                 0
# 3             Raebareli 2020-08-29        Rajesh     Kumar                 0
# 4              Dehradun 2020-08-29     Akanksha     Kunwar                 0
# ..                  ...        ...           ...       ...               ...
# 218              Bhopal 2020-08-30      Samyamoy   Debnath                 6
# 219  Bhubaneswar,Patna  2020-08-30        Anshul       Jha                 6
# 220               Delhi 2020-08-30        Prasad         B                 6
# 221            Guwahati 2020-08-30       Samarth      Jain                 6
# 222           New Delhi 2020-08-30         Summy   Anthony                 6
#
#      year  month  day
# ...

# %%
dataset.drop(['Date'], axis=1)
# Out:
#                    City     FirstName  LastName NameofMasterclass  year  \
# 0                Mumbai           Raj      Maru                 0  2020
# 1            Moradabad        Prachi   Agarwal                  0  2020
# 2              Guwahati  Paramananda       Deka                 0  2020
# 3             Raebareli        Rajesh     Kumar                 0  2020
# 4              Dehradun     Akanksha     Kunwar                 0  2020
# ..                  ...           ...       ...               ...   ...
# 218              Bhopal      Samyamoy   Debnath                 6  2020
# 219  Bhubaneswar,Patna         Anshul       Jha                 6  2020
# 220               Delhi        Prasad         B                 6  2020
# 221            Guwahati       Samarth      Jain                 6  2020
# 222           New Delhi         Summy   Anthony                 6  2020
#
#      month  day
# 0        8   29
# 1        8   29
# 2        8   29
# 3        8   29
# ...

# %%
dataset.to_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\All Masterclasses.xlsx')
