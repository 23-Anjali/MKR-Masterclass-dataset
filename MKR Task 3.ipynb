# %%
import pandas as pd                        #Importing the esential libraries
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\Anjali\\notebooks\\Untitled Folder'

# %%
df = pd.read_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\9,000- Investors.xlsx')

# %%
df.head(4)
# Out:
#                         Firm                        Website  \
# 0                  Techstars              www.techstars.com
# 1               Y Combinator            www.ycombinator.com
# 2  Plug and Play Tech Center  www.plugandplaytechcenter.com
# 3      Microsoft Accelerator   www.microsoftaccelerator.com
#
#                                          Description           Contact  \
# 0  Techstars is a mentorship-driven seed stage in...       David Cohen
# 1  Y Combinator is an accelerator that provides s...  Trevor Blackwell
# 2  Plug and Play is a global accelerator that spe...      Marc Steiner
# 3  Microsoft Accelerator is an accelerator that p...      Amir Pinchas
#
#         Phone Number                                              Title  \
# 0  +1 (408) 524-1400  Co-Founder, Co-Chief Executive Officer & Board...
# 1                NaN                               Co-Founder & Partner
# 2  +1 (650) 614-4800                                    General Counsel
# ...

# %%
df.shape
# Out:
# (9275, 20)

# %%
df = df.dropna(axis = 0)

# %%
df = df.dropna(axis = 1)

# %%
df.head()
# Out:
#                          Firm                 Website  \
# 80                   Mayfield        www.mayfield.com
# 86    Draper Fisher Jurvetson             www.dfj.com
# 135          Grotech Ventures         www.grotech.com
# 190           Edison Partners  www.edisonpartners.com
# 274  Tribeca Venture Partners       www.tribecavp.com
#
#                                            Description             Contact  \
# 80   Mayfield Fund is a venture capital firm which ...       Kamini Ramani
# 86   Draper Fisher Jurvetson is a venture capital f...  Mark J. Greenstein
# 135  Grotech Ventures is a Vienna, Virginia based v...   Charles P. Cullen
# 190  Edison Partners is a growth equity firm based ...  Kelly Ford Buckley
# 274  Tribeca Venture Partners is a venture capital ...        Brian Hirsch
#
#           Phone Number                                      Title  \
# 80   +1 (415) 493-8264                Vice President of Marketing
# ...

# %%
df.shape
# Out:
# (52, 20)

# %%
df.columns
# Out:
# Index(['Firm', 'Website', 'Description', 'Contact', 'Phone Number', 'Title',
#        'Email', 'Total Investments', 'Active Investments', 'Dry Powder',
#        'Notes', 'Notes 2', 'Preferred Sectors', 'Preferred Investment Size',
#        'Preferred Transaction Sizes', 'Preferences',
#        'Date of Last Fund Closed', 'AUM', 'Type', 'HQ'],
#       dtype='object')

# %%
df = df.drop(['Contact'] , axis =1)

# %%
df.columns
# Out:
# Index(['Firm', 'Website', 'Description', 'Phone Number', 'Title', 'Email',
#        'Total Investments', 'Active Investments', 'Dry Powder', 'Notes',
#        'Notes 2', 'Preferred Sectors', 'Preferred Investment Size',
#        'Preferred Transaction Sizes', 'Preferences',
#        'Date of Last Fund Closed', 'AUM', 'Type', 'HQ'],
#       dtype='object')

# %%
df = df.drop(['Description'] , axis =1)

# %%
df= df.drop(['Phone Number','Email','Notes', 'Notes 2' ,'Preferred Sectors','Preferred Investment Size', 'Website','Title'] , axis =1)

# %%
df.columns
# Out:
# Index(['Firm', 'Total Investments', 'Active Investments', 'Dry Powder',
#        'Preferred Transaction Sizes', 'Preferences',
#        'Date of Last Fund Closed', 'AUM', 'Type', 'HQ'],
#       dtype='object')

# %%
df
# Out:
#                                       Firm  Total Investments  \
# 80                                Mayfield               51.0
# 86                 Draper Fisher Jurvetson               56.0
# 135                       Grotech Ventures               31.0
# 190                        Edison Partners               30.0
# 274               Tribeca Venture Partners               22.0
# 293                         Altos Ventures               31.0
# 406                           Opus Capital               14.0
# 434                             DFJ Growth               16.0
# 473                Atlantic Bridge Capital               14.0
# 476                               Beringea               13.0
# 489                      StarVest Partners               14.0
# 493                      Peterson Partners               17.0
# 507                Hercules Capital (HTGC)               32.0
# 633                      Queen City Angels               13.0
# ...

# %%
df.to_excel('C:\\Users\\Anjali\\notebooks\\Untitled Folder\\Investor.xlsx')
